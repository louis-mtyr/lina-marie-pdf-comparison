# %% [markdown]
# # Easy Method

# %%
import difflib
import nltk
from sentence_transformers import SentenceTransformer, util
import pandas as pd
from pdfminer.high_level import extract_text
import time
import fitz
import pytesseract
from PIL import Image
import io
import re
import pickle

# %%
nltk.download('punkt')
model = SentenceTransformer('all-mpnet-base-v2')  # Léger mais performant

# %%
decoup1 = None
decoup_page1 = None
decoup2 = None
decoup_page2 = None

# === 1.1 Charger les textes depuis PDF ===
def load_book(pdf_path):
    text = extract_text(pdf_path)
    return text

# === 1.2 Charger les textes depuis PDF avec OCR ===
def split_paragraphs_from_ocr_text(ocr_text, min_length=100):
    lines = ocr_text.splitlines()
    paragraphs = []
    buffer = ""

    for line in lines:
        line = line.strip()
        if not line:
            continue

        buffer += " " + line if buffer else line

        if re.search(r'[.!?…]$|["»]$', line.strip()):
            if len(buffer.strip()) >= min_length:
                paragraphs.append(buffer.strip())
            buffer = ""

    if buffer and len(buffer.strip()) >= min_length:
        paragraphs.append(buffer.strip())

    return paragraphs

def extract_text_ocr(pdf_path):
    doc = fitz.open(pdf_path)
    paragraphs = []
    paragraph_to_page = []

    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        pix = page.get_pixmap(dpi=300)
        img = Image.open(io.BytesIO(pix.tobytes("png")))

        text = pytesseract.image_to_string(img, lang="fra")  # ou 'eng' selon la langue
        page_paragraphs = split_paragraphs_from_ocr_text(text)

        for p in page_paragraphs:
            paragraphs.append(p)
            paragraph_to_page.append(page_num + 1)

    return paragraphs, paragraph_to_page

# === 2. Segmenter le texte (par paragraphe ou par phrase) ===
def segment_text(text, level='paragraph'):
    if level == 'paragraph':
        return [p.strip() for p in text.split('\n\n') if len(p.strip()) > 50]
    elif level == 'sentence':
        return nltk.sent_tokenize(text)
    else:
        raise ValueError("level must be 'paragraph' or 'sentence'")

# === 3.1 Aligner les segments dans l'ordre (approche naïve) ===
def align_texts(texts1, texts2):
    min_len = min(len(texts1), len(texts2))
    return list(zip(texts1[:min_len], texts2[:min_len]))

# === 3.2 Aligner les segments dans l'ordre (approche sémantique) ===
def align_texts_semantically(v1_segments, v2_segments, threshold=0.90):
    emb1 = model.encode(v1_segments, convert_to_tensor=True)
    emb2 = model.encode(v2_segments, convert_to_tensor=True)

    alignment = []
    used_v2 = set()
    print("len embedding: ", len(emb1))

    for i, vec1 in enumerate(emb1):
        if i % 1000 == 0:
            print(f'On est à l\'étape {i}')
        sims = util.cos_sim(vec1, emb2)[0]
        best_idx = sims.argmax().item()
        best_score = sims[best_idx].item()

        if best_score >= threshold and best_idx not in used_v2:
            alignment.append((i, best_idx, v1_segments[i], v2_segments[best_idx], best_score))
            used_v2.add(best_idx)
        else:
            alignment.append((i, None, v1_segments[i], "", best_score))  # paragraphe sans match

    return alignment

# === 4. Comparaison textuelle ===
def diff_ratio(a, b):
    return difflib.SequenceMatcher(None, a, b).ratio()

# === 5. Comparaison sémantique ===
def semantic_similarity(a, b):
    emb1 = model.encode(a, convert_to_tensor=True)
    emb2 = model.encode(b, convert_to_tensor=True)
    return float(util.cos_sim(emb1, emb2))

# === 6. Comparaison complète et rapport CSV ===
def compare_books(book1_path, book2_path, init_time, sim_threshold=0.90):
    print('DEBUT DE L\'ALGO')

    # v1_segments, v1_pages = extract_text_ocr(book1_path)
    # print(v1_segments[30:34])
    # print(v1_pages[30:34])
    # save_ocr_output(v1_segments, v1_pages, 'ocr_nouveau.pkl')
    # print('TEXT 1 IMPORTE')

    # print("Temps: ", time.time() - init_time)
    # v2_segments, v2_pages = extract_text_ocr(book2_path)
    # print(v2_segments[30:34])
    # print(v2_pages[30:34])
    # save_ocr_output(v2_segments, v2_pages, 'ocr_ancien.pkl')
    # print('TEXT 2 IMPORTE')
    # print("Temps: ", time.time() - init_time)

    v1_segments, v1_pages = load_ocr_output('ocr_nouveau.pkl')
    v2_segments, v2_pages = load_ocr_output('ocr_ancien.pkl')

    aligned = align_texts_semantically(v1_segments, v2_segments, threshold=sim_threshold)
    print('ALIGN TERMINE')
    print("Temps: ", time.time() - init_time)
    print('len align: ', len(aligned))

    report = []

    for i, j, seg1, seg2, sim in aligned:
        diff = diff_ratio(seg1, seg2) if seg2 else 0.0

        if diff < 0.95 or sim < sim_threshold:
            report.append({
                'index_v1': i,
                'index_v2': j if j is not None else 'NO_MATCH',
                'page_v1': v1_pages[i],
                'page_v2': v2_pages[j] if j is not None else 'NO_MATCH',
                'text_v1': seg1,
                'text_v2': seg2,
                'textual_similarity': round(diff, 3),
                'semantic_similarity': round(sim, 3)
            })

    return pd.DataFrame(report)

# utils
def save_ocr_output(paragraphs, pages, filename):
    with open(filename, 'wb') as f:
        pickle.dump((paragraphs, pages), f)

def load_ocr_output(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# %%
# === 7. Utilisation ===
if __name__ == "__main__":
    df_diff = compare_books('documents/nouveau.pdf', 'documents/ancien.pdf', init_time=time.time())
    df_diff.to_csv('differences3.csv', index=False)
    print(df_diff.head())

# %% [markdown]
# # Color part

# %%
import fitz  # PyMuPDF
from collections import defaultdict

def extract_paragraphs(pdf_path, line_spacing_threshold=10):
    doc = fitz.open(pdf_path)
    paragraphs = defaultdict(list)

    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        blocks = page.get_text("dict")["blocks"]

        for block in blocks:
            if "lines" not in block:
                continue

            lines_data = []

            for line in block["lines"]:
                y_top = line["bbox"][1]
                line_text = ""
                colors = set()

                for span in line["spans"]:
                    line_text += span["text"].strip() + " "
                    colors.add(span["color"])

                if line_text.strip():
                    lines_data.append({
                        "text": " ".join(line_text.strip().split()),
                        "y": y_top,
                        "colors": colors
                    })

            # Regroupe les lignes proches en paragraphes
            current_para = ""
            current_colors = set()
            last_y = None

            for line in lines_data:
                if last_y is not None and abs(line["y"] - last_y) > line_spacing_threshold:
                    # saut de paragraphe
                    text = current_para.strip()
                    if text:
                        paragraphs[text].append((page_num + 1, tuple(current_colors)))
                    current_para = ""
                    current_colors = set()

                current_para += line["text"] + " "
                current_colors.update(line["colors"])
                last_y = line["y"]

            # dernier paragraphe du bloc
            text = current_para.strip()
            if text:
                paragraphs[text].append((page_num + 1, tuple(current_colors)))

    return paragraphs

def int_to_rgb(color_int):
    """Convertit une couleur entière en tuple (R, G, B)"""
    r = (color_int >> 16) & 255
    g = (color_int >> 8) & 255
    b = color_int & 255
    return (r, g, b)

def is_grayscale(rgb, tolerance=15):
    """Renvoie True si la couleur est proche d'un gris (R ≈ G ≈ B)"""
    r, g, b = rgb
    return abs(r - g) < tolerance and abs(g - b) < tolerance and abs(r - b) < tolerance

def is_nearly_black(rgb, threshold=90):
    return sum(rgb) < threshold  # proche de (0, 0, 0)

def is_nearly_white(rgb, threshold=90):
    return sum(255 - c for c in rgb) < threshold  # proche de (255, 255, 255)

def is_significant_color(rgb):
    return not ((is_nearly_black(rgb) or is_nearly_white(rgb)))

def color_distance(c1, c2):
    """Distance euclidienne simple entre deux couleurs RGB"""
    r1, g1, b1 = int_to_rgb(c1)
    r2, g2, b2 = int_to_rgb(c2)
    return ((r2 - r1) ** 2 + (g2 - g1) ** 2 + (b2 - b1) ** 2) ** 0.5

def colors_are_significantly_different(set1, set2, threshold=380):
    """Vrai si une couleur de set1 diffère visiblement d'une de set2"""
    

    for c1 in set1:
        for c2 in set2:
            rgb1 = int_to_rgb(c1)
            rgb2 = int_to_rgb(c2)

            # Ignore les gris ou blancs/noirs neutres
            if not is_significant_color(rgb1) and not is_significant_color(rgb2):
                continue  # on saute cette comparaison
        
            if color_distance(c1, c2) >= threshold:
                return True
    return False


def compare_paragraphs(map1, map2):
    changed = []

    for para in map1:
        if para in map2:
            colors1 = set()
            pages1 = set()
            for page, color_set in map1[para]:
                colors1.update(color_set)
                pages1.add(page)

            colors2 = set()
            pages2 = set()
            for page, color_set in map2[para]:
                colors2.update(color_set)
                pages2.add(page)

            if colors_are_significantly_different(colors1, colors2):
                changed.append({
                    "text": para,
                    "colors_v1": colors1,
                    "colors_v2": colors2,
                    "pages_v1": pages1,
                    "pages_v2": pages2
                })

    return changed


if __name__ == "__main__":
    file_v1 = "documents/ancien_clean.pdf"
    file_v2 = "documents/nouveau.pdf"

    print("🔍 Extraction de paragraphes de l'ancien PDF...")
    paras_v1 = extract_paragraphs(file_v1)

    print("🔍 Extraction de paragraphes du nouveau PDF...")
    paras_v2 = extract_paragraphs(file_v2)

    print("🔎 Comparaison...")
    changed = compare_paragraphs(paras_v1, paras_v2)

    print(f"\n🟠 Paragraphes avec changement de couleur : {len(changed)}\n")
    for idx, entry in enumerate(changed, 1):
        short = entry['text'][:150].replace("\n", " ") + ("..." if len(entry['text']) > 150 else "")
        print(f"{idx}. 📄 Texte : {short}")
        print(f"   🧾 Pages ancien PDF : {sorted(entry['pages_v1'])}")
        print(f"   🎨 Couleurs ancien PDF : {entry['colors_v1']}")
        print(f"   🧾 Pages nouveau PDF : {sorted(entry['pages_v2'])}")
        print(f"   🎨 Couleurs nouveau PDF : {entry['colors_v2']}")
        print("-" * 80)

    # ✅ Extraire les couples uniques de pages avec changement de couleur
    page_pairs = set()

    for idx, entry in enumerate(changed, 1):
        page_pairs.add((tuple(entry['pages_v1']), tuple(entry['pages_v2'])))

    # 📤 Affichage final
    print(f"\n📘 Couples de pages avec changement de couleur détecté ({len(page_pairs)} couples uniques) :\n")
    for p1, p2 in sorted(page_pairs):
        print(f"Ancien PDF : page {p1}  ⇄  Nouveau PDF : page {p2}")
# Out:
# 🔍 Extraction de paragraphes de l'ancien PDF...
# 🔍 Extraction de paragraphes du nouveau PDF...
# 🔎 Comparaison...
#
# 🟠 Paragraphes avec changement de couleur : 244
#
# 1. 📄 Texte : X
#    🧾 Pages ancien PDF : [12, 689, 690, 691, 692, 693, 694, 695, 696, 726, 727, 728, 729, 730, 731, 732, 733, 734, 736, 737, 738, 739, 740, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 756, 758, 759, 760, 761, 762, 763, 764, 765, 767, 768, 769, 770]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [11, 666, 667, 668, 669, 671, 673, 674, 676, 677, 678, 679, 680, 682, 684, 686, 687, 688, 689, 690, 691, 692, 693, 694, 695, 696, 698, 699, 700, 701, 702, 703, 704, 705, 706, 707, 708, 710, 713]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 2. 📄 Texte : A Connaissances fondamentales que tout étudiant doit connaître en fin de deuxième cycle.
#    🧾 Pages ancien PDF : [27]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [26]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 3. 📄 Texte : 3
#    🧾 Pages ancien PDF : [39, 68, 517, 518, 559, 561, 573]
#    🎨 Couleurs ancien PDF : {2301728, 695875, 16777215}
#    🧾 Pages nouveau PDF : [38, 67, 68, 70, 72, 74, 76, 452, 489, 490, 502]
#    🎨 Couleurs nouveau PDF : {1340219, 15505275, 3683380, 16777215}
# --------------------------------------------------------------------------------
# 4. 📄 Texte : 1
#    🧾 Pages ancien PDF : [39, 517, 518, 559, 561, 571, 573]
#    🎨 Couleurs ancien PDF : {2301728, 695875, 16777215}
#    🧾 Pages nouveau PDF : [38, 40, 42, 44, 46, 48, 452, 453, 489, 490, 500, 502]
#    🎨 Couleurs nouveau PDF : {1340219, 15505275, 3683380, 16777215}
# --------------------------------------------------------------------------------
# 5. 📄 Texte : 4
#    🧾 Pages ancien PDF : [40, 79, 517, 559, 561, 573]
#    🎨 Couleurs ancien PDF : {2301728, 695875, 16777215}
#    🧾 Pages nouveau PDF : [39, 77, 78, 80, 82, 84, 265, 489, 490, 502]
#    🎨 Couleurs nouveau PDF : {15505275, 3683380, 16777215}
# --------------------------------------------------------------------------------
# 6. 📄 Texte : B Définition Principes et finalités
#    🧾 Pages ancien PDF : [40]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [39]
#    🎨 Couleurs nouveau PDF : {2894120, 1269409, 16777215}
# --------------------------------------------------------------------------------
# 7. 📄 Texte : 5
#    🧾 Pages ancien PDF : [41, 90, 561]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [40, 86, 88, 90, 92, 94, 96, 489, 490]
#    🎨 Couleurs nouveau PDF : {15505275, 3683380, 16777215}
# --------------------------------------------------------------------------------
# 8. 📄 Texte : 6
#    🧾 Pages ancien PDF : [42, 102, 559, 561]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [41, 97, 98, 100, 102, 104, 106, 108, 265, 489, 490]
#    🎨 Couleurs nouveau PDF : {15505275, 3683380, 16777215}
# --------------------------------------------------------------------------------
# 9. 📄 Texte : 9
#    🧾 Pages ancien PDF : [45, 147, 319, 559]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [44, 137, 138, 140, 142, 144, 146, 148, 278, 489]
#    🎨 Couleurs nouveau PDF : {2894120, 15505275, 3683380, 16777215}
# --------------------------------------------------------------------------------
# 10. 📄 Texte : 10
#    🧾 Pages ancien PDF : [46, 160, 559]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [45, 150, 152, 154, 156, 158, 160, 265, 489]
#    🎨 Couleurs nouveau PDF : {15505275, 3683380, 16777215}
# --------------------------------------------------------------------------------
# 11. 📄 Texte : C Avec les progrès de la médecine périnatale, on parvient de mieux en mieux à réanimer des
#    🧾 Pages ancien PDF : [48]
#    🎨 Couleurs ancien PDF : {2301728, 695875, 16777215}
#    🧾 Pages nouveau PDF : [48]
#    🎨 Couleurs nouveau PDF : {1340219, 16777215}
# --------------------------------------------------------------------------------
# 12. 📄 Texte : 2
#    🧾 Pages ancien PDF : [52, 517, 518, 559, 571, 573]
#    🎨 Couleurs ancien PDF : {2301728, 695875, 16777215}
#    🧾 Pages nouveau PDF : [50, 52, 54, 56, 58, 60, 62, 64, 66, 265, 452, 453, 489, 500, 502]
#    🎨 Couleurs nouveau PDF : {1340219, 15505275, 3683380, 16777215}
# --------------------------------------------------------------------------------
# 13. 📄 Texte : A Définition Connaître la définition et les différents
#    🧾 Pages ancien PDF : [52]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [50]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 14. 📄 Texte : B Définition Connaître les applications médicales
#    🧾 Pages ancien PDF : [52]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [50]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 15. 📄 Texte : B Prise en charge Connaître les objectifs de la prise
#    🧾 Pages ancien PDF : [52]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [51]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 16. 📄 Texte : 16
#    🧾 Pages ancien PDF : [53, 234, 319]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [51, 213, 214, 216, 218, 220, 222, 224, 226, 228, 230, 232, 265, 278]
#    🎨 Couleurs nouveau PDF : {2894120, 15505275, 3683380, 16777215}
# --------------------------------------------------------------------------------
# 17. 📄 Texte : • A Harcèlement sexuel (article 222-33 du Code pénal) :
#    🧾 Pages ancien PDF : [53]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [52]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 18. 📄 Texte : B Diagnostic positif Identifier les lésions associées tégumentaires et psychiques
#    🧾 Pages ancien PDF : [53]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [51]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 19. 📄 Texte : B Diagnostic positif Identifier une mutilation sexuelle féminine ou masculine
#    🧾 Pages ancien PDF : [53]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [51]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 20. 📄 Texte : • A Corruption de mineur (commis par un majeur) (article 227-22 du Code pénal) :
#    🧾 Pages ancien PDF : [54]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [52]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 21. 📄 Texte : • A Proposition sexuelle :
#    🧾 Pages ancien PDF : [54]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [52]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 22. 📄 Texte : • A Pédopornographie :
#    🧾 Pages ancien PDF : [54]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [53]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 23. 📄 Texte : • A Atteinte sexuelle (article 227-25 du Code pénal) :
#    🧾 Pages ancien PDF : [54]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [53]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 24. 📄 Texte : • A Agression sexuelle :
#    🧾 Pages ancien PDF : [54]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [53]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 25. 📄 Texte : • A Viol :
#    🧾 Pages ancien PDF : [54]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [53]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 26. 📄 Texte : B Les données statistiques sur les violences sexuelles en France demeurent relativement frag-
#    🧾 Pages ancien PDF : [55]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 16777215}
#    🧾 Pages nouveau PDF : [54]
#    🎨 Couleurs nouveau PDF : {1269409, 16777215}
# --------------------------------------------------------------------------------
# 27. 📄 Texte : B Le certificat peut être établi :
#    🧾 Pages ancien PDF : [57]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 16777215}
#    🧾 Pages nouveau PDF : [57]
#    🎨 Couleurs nouveau PDF : {1269409, 16777215}
# --------------------------------------------------------------------------------
# 28. 📄 Texte : A Deux situations cliniques peuvent amener à modifier la prise en charge :
#    🧾 Pages ancien PDF : [59]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [59]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 29. 📄 Texte : 28
#    🧾 Pages ancien PDF : [65, 319, 586]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [63, 278, 513, 514, 516, 518, 520, 522, 524, 526, 528, 530]
#    🎨 Couleurs nouveau PDF : {2894120, 15505275, 16777215}
# --------------------------------------------------------------------------------
# 30. 📄 Texte : A Définition Définition de la grossesse extra-utérine (GEU)
#    🧾 Pages ancien PDF : [68]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [67]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 31. 📄 Texte : B Physiopathologie Évolution naturelle de la GEU
#    🧾 Pages ancien PDF : [68]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [67]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 32. 📄 Texte : B
#    🧾 Pages ancien PDF : [72, 548, 561, 821]
#    🎨 Couleurs ancien PDF : {2301728, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [71, 478, 480, 490, 727]
#    🎨 Couleurs nouveau PDF : {0, 14165546, 3683380, 16777215}
# --------------------------------------------------------------------------------
# 33. 📄 Texte : A Définition Définition du syndrome prémenstruel
#    🧾 Pages ancien PDF : [80]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [77, 87]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 34. 📄 Texte : A Définition Définition du cycle menstruel normal
#    🧾 Pages ancien PDF : [80]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [77, 87]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 35. 📄 Texte : B Suivi et/ou pronostic Connaître les conséquences cliniques des troubles du cycle
#    🧾 Pages ancien PDF : [80]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [77, 87]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 36. 📄 Texte : A Étiologie Connaître les principales causes de métrorragies
#    🧾 Pages ancien PDF : [80]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [77, 87]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 37. 📄 Texte : A Étiologie Connaître les principales causes de ménorragies
#    🧾 Pages ancien PDF : [80]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [77, 87]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 38. 📄 Texte : B Étiologie Connaître les principales étiologies de spanioménorrhée
#    🧾 Pages ancien PDF : [80]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [77, 87]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 39. 📄 Texte : A Étiologie Différencier les causes organiques et les causes fonctionnelles
#    🧾 Pages ancien PDF : [80]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [78]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 40. 📄 Texte : A Examens complémentaires Savoir prescrire les premiers examens biologiques à réaliser
#    🧾 Pages ancien PDF : [80]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [78]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 41. 📄 Texte : Fig. 4.2. B Classification FIGO 2011 des myomes utérins.
#    🧾 Pages ancien PDF : [86]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [84]
#    🎨 Couleurs nouveau PDF : {1269409, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 42. 📄 Texte : Tableau 4.3. B Classification FIGO 2011 des myomes utérins.
#    🧾 Pages ancien PDF : [86]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [84]
#    🎨 Couleurs nouveau PDF : {1269409, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 43. 📄 Texte : 50
#    🧾 Pages ancien PDF : [88, 319]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [85, 278]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 44. 📄 Texte : B Éléments
#    🧾 Pages ancien PDF : [90, 103, 115, 173, 181, 261, 284, 329, 347, 449, 450, 558, 586, 634, 654]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [77, 87, 109, 162, 171, 234, 249, 286, 303, 394, 395, 485, 547, 556, 565, 574]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 45. 📄 Texte : A Diagnostic
#    🧾 Pages ancien PDF : [90, 347, 348, 380, 381, 440, 528, 529, 557]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [532, 533]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 46. 📄 Texte : B Étiologie Connaître les principales causes
#    🧾 Pages ancien PDF : [90]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [86]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 47. 📄 Texte : B Étiologie Connaître les principales étiologies des hyperprolactinémies
#    🧾 Pages ancien PDF : [91]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [87]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 48. 📄 Texte : A Le syndrome prémenstruel (SPM) représente la gêne fonctionnelle la plus fréquemment
#    🧾 Pages ancien PDF : [98]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [95]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 49. 📄 Texte : 60
#    🧾 Pages ancien PDF : [99, 319]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [95, 278]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 50. 📄 Texte : A Il existe classiquement trois principaux signes :
#    🧾 Pages ancien PDF : [99]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [95]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 51. 📄 Texte : B Il comprend :
#    🧾 Pages ancien PDF : [99, 219]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 16777215}
#    🧾 Pages nouveau PDF : [96, 200]
#    🎨 Couleurs nouveau PDF : {1269409, 16777215}
# --------------------------------------------------------------------------------
# 52. 📄 Texte : B Prévalence,
#    🧾 Pages ancien PDF : [102, 132, 195, 235, 260, 284, 329, 347, 380, 406, 449, 586, 618, 654]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [67, 123, 183, 184, 233, 249, 250, 286, 303, 332, 355, 394, 540, 574]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 53. 📄 Texte : A Diagnostic positif Connaître les symptômes du syndrome climatérique
#    🧾 Pages ancien PDF : [102]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [97]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 54. 📄 Texte : B Diagnostic positif Savoir distinguer des bouffées de chaleur typiques et atypiques
#    🧾 Pages ancien PDF : [102]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [97]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 55. 📄 Texte : B Prise en charge Connaître les principes du traitement hormonal de la ménopause (THM)
#    🧾 Pages ancien PDF : [103]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [97]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 56. 📄 Texte : B Prise en charge Connaître les contre-indications du THM
#    🧾 Pages ancien PDF : [103]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [97]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 57. 📄 Texte : B Prise en charge Connaître la balance bénéfice-risque du THM en cas de ménopause naturelle
#    🧾 Pages ancien PDF : [103]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [97]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 58. 📄 Texte : B Prise en charge Savoir informer des mesures éducatives et hygiéno-diététiques de la femme
#    🧾 Pages ancien PDF : [103]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [98]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 59. 📄 Texte : A Diagnostic positif Savoir que toute métrorragie chez une femme ménopausée doit être explorée
#    🧾 Pages ancien PDF : [103]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [98]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 60. 📄 Texte : B Avant la ménopause, les maladies coronariennes sont beaucoup plus fréquentes chez
#    🧾 Pages ancien PDF : [108]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 16777215}
#    🧾 Pages nouveau PDF : [102]
#    🎨 Couleurs nouveau PDF : {1269409, 16777215}
# --------------------------------------------------------------------------------
# 61. 📄 Texte : 70
#    🧾 Pages ancien PDF : [109, 319]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [105, 278]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 62. 📄 Texte : A Définition Connaître les différentes modalités de contraceptions existantes
#    🧾 Pages ancien PDF : [115]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [109]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 63. 📄 Texte : B Suivi et/ou
#    🧾 Pages ancien PDF : [116, 381]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [183]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 64. 📄 Texte : B Prise en charge Savoir prescrire une contraception chez les femmes à risque vasculaire
#    🧾 Pages ancien PDF : [116]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [110]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 65. 📄 Texte : B Prise en charge Connaître les modalités de prescription chez la jeune femme mineure
#    🧾 Pages ancien PDF : [116]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [110]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 66. 📄 Texte : A La COP comprend deux types de molécules :
#    🧾 Pages ancien PDF : [117]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [112]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 67. 📄 Texte : 80
#    🧾 Pages ancien PDF : [120, 319]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [115, 278]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 68. 📄 Texte : A Ces petites doses de progestatif délivrées en continu peuvent être utilisées selon plusieurs
#    🧾 Pages ancien PDF : [121]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [114]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 69. 📄 Texte : • A la prise de médicaments notamment inducteurs enzymatiques :
#    🧾 Pages ancien PDF : [126]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [118]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 70. 📄 Texte : A Prévalence,
#    🧾 Pages ancien PDF : [133, 260, 261, 284, 406]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [123, 233, 234, 250, 355]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 71. 📄 Texte : B Prise en charge Connaître les contre-indications des différentes méthodes
#    🧾 Pages ancien PDF : [133]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [124]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 72. 📄 Texte : B Prise en charge Connaître les déterminants du choix contraceptif après IVG
#    🧾 Pages ancien PDF : [133]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [124]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 73. 📄 Texte : Tableau 8.2. B Comparaison entre IVG instrumentale et IVG médicamenteuse.
#    🧾 Pages ancien PDF : [138]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [129]
#    🎨 Couleurs nouveau PDF : {1269409, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 74. 📄 Texte : Tableau 8.3. B Contraception après une IVG.
#    🧾 Pages ancien PDF : [144]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [136]
#    🎨 Couleurs nouveau PDF : {1269409, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 75. 📄 Texte : B Épidémiologie,
#    🧾 Pages ancien PDF : [147]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [137]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 76. 📄 Texte : B Examens
#    🧾 Pages ancien PDF : [148, 161, 173, 182, 195, 235, 284, 285, 329, 406, 450, 529, 618, 654]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 16777215}
#    🧾 Pages nouveau PDF : [67, 137, 150, 162, 171, 184, 250, 286, 287, 304, 355, 385, 395, 461, 540, 574]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 77. 📄 Texte : Fig. 9.2. B Hystérosalpingographie.
#    🧾 Pages ancien PDF : [153]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [144]
#    🎨 Couleurs nouveau PDF : {1269409, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 78. 📄 Texte : C Peuvent être réalisées :
#    🧾 Pages ancien PDF : [154]
#    🎨 Couleurs ancien PDF : {2301728, 695875, 16777215}
#    🧾 Pages nouveau PDF : [145]
#    🎨 Couleurs nouveau PDF : {1340219, 16777215}
# --------------------------------------------------------------------------------
# 79. 📄 Texte : B Le recueil de sperme pour un spermogramme est réalisé par masturbation au laboratoire,
#    🧾 Pages ancien PDF : [155]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 16777215}
#    🧾 Pages nouveau PDF : [146]
#    🎨 Couleurs nouveau PDF : {1269409, 16777215}
# --------------------------------------------------------------------------------
# 80. 📄 Texte : Tableau 9.1. B Paramètres du sperme.
#    🧾 Pages ancien PDF : [155]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [146]
#    🎨 Couleurs nouveau PDF : {1269409, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 81. 📄 Texte : A Étiologie Connaître les principales indications des inséminations artificielles
#    🧾 Pages ancien PDF : [160]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [150]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 82. 📄 Texte : A Étiologie Connaître les principales indications de la FIV avec ou sans ICSI
#    🧾 Pages ancien PDF : [160]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [150]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 83. 📄 Texte : Fig. 10.1. A Étapes de la fécondation in vitro.
#    🧾 Pages ancien PDF : [165]
#    🎨 Couleurs ancien PDF : {2301728, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [155]
#    🎨 Couleurs nouveau PDF : {2894120, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 84. 📄 Texte : A Définition Définition de la douleur pelvienne aiguë (DPA) et chronique (DPC)
#    🧾 Pages ancien PDF : [173]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [162]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 85. 📄 Texte : A Diagnostic positif Interrogatoire et examen clinique utile au diagnostic des DPA
#    🧾 Pages ancien PDF : [173]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [162]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 86. 📄 Texte : A Définition Savoir distinguer les douleurs chroniques des douleurs aiguës
#    🧾 Pages ancien PDF : [173]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [162]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 87. 📄 Texte : A Examens
#    🧾 Pages ancien PDF : [174, 235, 236]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [67, 162, 548]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 88. 📄 Texte : Tableau 11.1. A Étiologie des douleurs pelviennes aiguës de la femme.
#    🧾 Pages ancien PDF : [175]
#    🎨 Couleurs ancien PDF : {2301728, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [164]
#    🎨 Couleurs nouveau PDF : {2894120, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 89. 📄 Texte : Fig. 11.1. A Orientation diagnostique devant une douleur pelvienne aiguë.
#    🧾 Pages ancien PDF : [176]
#    🎨 Couleurs ancien PDF : {2301728, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [165]
#    🎨 Couleurs nouveau PDF : {2894120, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 90. 📄 Texte : B En cas de doute diagnostique entre une grossesse arrêtée et une GEU, la recherche de vil-
#    🧾 Pages ancien PDF : [179]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 16777215}
#    🧾 Pages nouveau PDF : [169]
#    🎨 Couleurs nouveau PDF : {1269409, 16777215}
# --------------------------------------------------------------------------------
# 91. 📄 Texte : A Cet examen peut être utile dans les cas de doute entre une IGH et une appendicite aiguë
#    🧾 Pages ancien PDF : [180]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [169]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 92. 📄 Texte : A Étiologie Connaître les deux étiologies les plus
#    🧾 Pages ancien PDF : [195]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [183]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 93. 📄 Texte : A Diagnostic positif Connaître les symptômes et les éléments
#    🧾 Pages ancien PDF : [195]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [183]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 94. 📄 Texte : B Étiologie Kyste ovarien
#    🧾 Pages ancien PDF : [195]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [183]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 95. 📄 Texte : A Étiologie Savoir différencier kystes fonctionnel et organique
#    🧾 Pages ancien PDF : [195]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [183]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 96. 📄 Texte : A Définition Définir le prolapsus génital de la femme
#    🧾 Pages ancien PDF : [195]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [184]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 97. 📄 Texte : B Diagnostic positif Citer les diagnostics différentiels du prolapsus génital de la femme
#    🧾 Pages ancien PDF : [195]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [184]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 98. 📄 Texte : A Ce sont :
#    🧾 Pages ancien PDF : [199]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [189, 228]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 99. 📄 Texte : IRM
#    🧾 Pages ancien PDF : [209, 319]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [278]
#    🎨 Couleurs nouveau PDF : {16777215}
# --------------------------------------------------------------------------------
# 100. 📄 Texte : A Définition Définir les termes suivants : pubarche, thélarche et ménarche
#    🧾 Pages ancien PDF : [215]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [195]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 101. 📄 Texte : B Éléments physiopathologiques Connaître la valeur moyenne de la croissance pubertaire
#    🧾 Pages ancien PDF : [215]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [195]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 102. 📄 Texte : B Définition Connaître les différents stades de Tanner
#    🧾 Pages ancien PDF : [215]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [195]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 103. 📄 Texte : A Définition Définir la puberté précoce et la puberté avancée
#    🧾 Pages ancien PDF : [215]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [195]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 104. 📄 Texte : A Diagnostic positif Savoir interpréter une courbe de croissance
#    🧾 Pages ancien PDF : [216]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [195]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 105. 📄 Texte : B Étiologie Connaître les étiologies précises des pubertés précoces
#    🧾 Pages ancien PDF : [216]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [196]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 106. 📄 Texte : A Diagnostic positif Définir le retard pubertaire du garçon et de la fille
#    🧾 Pages ancien PDF : [216]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [196]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 107. 📄 Texte : B Contenu multimédia Courbe de croissance, précocité pubertaire
#    🧾 Pages ancien PDF : [216]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [196]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 108. 📄 Texte : B Contenu multimédia Premature thélarche
#    🧾 Pages ancien PDF : [216]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [196]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 109. 📄 Texte : B Contenu multimédia Adrénarche
#    🧾 Pages ancien PDF : [216]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [196]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 110. 📄 Texte : B Contenu multimédia Puberté précoce chez la fille
#    🧾 Pages ancien PDF : [216]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [196]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 111. 📄 Texte : A Lors de la puberté, la vulve se modifie. Elle passe de la position verticale à la position hori-
#    🧾 Pages ancien PDF : [217]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [198]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 112. 📄 Texte : Fig. 14.1. B Stades de Tanner chez la fille.
#    🧾 Pages ancien PDF : [217]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [198]
#    🎨 Couleurs nouveau PDF : {1269409, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 113. 📄 Texte : Fig. 14.2. B Stades de Tanner chez le garçon.
#    🧾 Pages ancien PDF : [218]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [199]
#    🎨 Couleurs nouveau PDF : {1269409, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 114. 📄 Texte : A Cliniquement, une puberté précoce doit être évoquée devant :
#    🧾 Pages ancien PDF : [219]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [200]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 115. 📄 Texte : A La sexualité est un élément fondamental de la qualité de vie, mesurable par des question-
#    🧾 Pages ancien PDF : [223]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [204]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 116. 📄 Texte : A Éléments
#    🧾 Pages ancien PDF : [223, 347, 380, 558]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [203, 303, 332, 485]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 117. 📄 Texte : B Étiologie Connaître les autres étiologies des principales dysfonctions sexuelles
#    🧾 Pages ancien PDF : [223]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [203]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 118. 📄 Texte : Fig. 15.1. A Réponses sexuelles de la femme selon le modèle de Masters et Johnson.
#    🧾 Pages ancien PDF : [224]
#    🎨 Couleurs ancien PDF : {2301728, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [205]
#    🎨 Couleurs nouveau PDF : {2894120, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 119. 📄 Texte : Fig. 15.2. A Sexualité féminine : approche MPSC.
#    🧾 Pages ancien PDF : [225]
#    🎨 Couleurs ancien PDF : {2301728, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [206]
#    🎨 Couleurs nouveau PDF : {2894120, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 120. 📄 Texte : A Étiologie Connaître les causes des IST selon leur expression clinique
#    🧾 Pages ancien PDF : [235]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [214]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 121. 📄 Texte : A Prise en charge Connaître les principes de prise en charge du ou des partenaires
#    🧾 Pages ancien PDF : [235]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [214]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 122. 📄 Texte : A Contenu multimédia Herpès génital
#    🧾 Pages ancien PDF : [235]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [214]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 123. 📄 Texte : A Contenu multimédia Syphilis primaire (chancre)
#    🧾 Pages ancien PDF : [235]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [214]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 124. 📄 Texte : B Diagnostic positif Connaître les manifestations extragénitales des IST
#    🧾 Pages ancien PDF : [235]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [214]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 125. 📄 Texte : B Prise en charge Connaître les mesures générales de prise en charge des IST (médicamenteuse
#    🧾 Pages ancien PDF : [235]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [214]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 126. 📄 Texte : A Prise en charge Connaître les modalités du traitement probabiliste des IST
#    🧾 Pages ancien PDF : [235]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [214]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 127. 📄 Texte : A Prise en charge Savoir traiter la syphilis primaire
#    🧾 Pages ancien PDF : [236]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [214]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 128. 📄 Texte : B Prise en charge Savoir traiter la syphilis secondaire
#    🧾 Pages ancien PDF : [236]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [214]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 129. 📄 Texte : A Suivi et/ou pronostic Principales conséquences à long terme des IGH chez la femme
#    🧾 Pages ancien PDF : [236]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [215]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 130. 📄 Texte : B Diagnostic positif Reconnaître les particularités des IST
#    🧾 Pages ancien PDF : [236]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [215]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 131. 📄 Texte : B Contenu multimédia Condylome* Photographie de condylomes
#    🧾 Pages ancien PDF : [236]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [215]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 132. 📄 Texte : A Nous développerons les infections à Chlamydia trachomatis , Neisseria gonorrhoeae et
#    🧾 Pages ancien PDF : [238]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [217]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 133. 📄 Texte : Fig. 16.1. A Algorithme pour le diagnostic sérologique de syphilis.
#    🧾 Pages ancien PDF : [241]
#    🎨 Couleurs ancien PDF : {2301728, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [219]
#    🎨 Couleurs nouveau PDF : {2894120, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 134. 📄 Texte : Tableau 16.2. B Recommandations et protocoles du CNGOF, IGH non compliquées.
#    🧾 Pages ancien PDF : [256]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [230]
#    🎨 Couleurs nouveau PDF : {2894120, 1269409, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 135. 📄 Texte : A Il comprend :
#    🧾 Pages ancien PDF : [257]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [231]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 136. 📄 Texte : B Étiologie Connaître les facteurs de risque génétiques*
#    🧾 Pages ancien PDF : [261]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [234]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 137. 📄 Texte : A Étiologie Connaître les facteurs de risque
#    🧾 Pages ancien PDF : [261]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [234]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 138. 📄 Texte : A Étiologie Alcool, tabac, sédentarité, surpoids, obésité, régime pauvre en fibre*
#    🧾 Pages ancien PDF : [261]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [234]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 139. 📄 Texte : A Définition Niveau de prévention : définitions
#    🧾 Pages ancien PDF : [261]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [234]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 140. 📄 Texte : A Définition Prévention selon la population : universelle, sélective ou ciblée
#    🧾 Pages ancien PDF : [261]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [234]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 141. 📄 Texte : A Définition Dépistage des cancers : conditions pour réaliser un dépistage organisé
#    🧾 Pages ancien PDF : [261]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [234]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 142. 📄 Texte : A Les lésions bénignes du col utérin sont essentiellement constituées par les lésions précancé-
#    🧾 Pages ancien PDF : [285]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [251]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 143. 📄 Texte : A Diagnostic positif Connaître les circonstances de découverte du cancer du corps utérin
#    🧾 Pages ancien PDF : [285]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [250]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 144. 📄 Texte : A Dans la majorité des cas, le cancer du col utérin répond aux caractéristiques suivantes :
#    🧾 Pages ancien PDF : [302]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [264]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 145. 📄 Texte : Tableau 18.2. C Classification clinique des cancers du col utérin selon la Fédération internationale de
#    🧾 Pages ancien PDF : [310]
#    🎨 Couleurs ancien PDF : {2301728, 695875, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [271]
#    🎨 Couleurs nouveau PDF : {2894120, 14165546, 1340219, 16777215}
# --------------------------------------------------------------------------------
# 146. 📄 Texte : Tableau 18.3. C Survie relative à 5 ans en fonction du stade.
#    🧾 Pages ancien PDF : [310]
#    🎨 Couleurs ancien PDF : {2301728, 695875, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [272]
#    🎨 Couleurs nouveau PDF : {2894120, 14165546, 1340219, 16777215}
# --------------------------------------------------------------------------------
# 147. 📄 Texte : B Le cancer du corps utérin est le quatrième cancer de la femme en France en 2018 en
#    🧾 Pages ancien PDF : [315]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 16777215}
#    🧾 Pages nouveau PDF : [275]
#    🎨 Couleurs nouveau PDF : {2894120, 1269409, 16777215}
# --------------------------------------------------------------------------------
# 148. 📄 Texte : B Définition Connaître les principaux types
#    🧾 Pages ancien PDF : [328, 348]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [249, 286, 304]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 149. 📄 Texte : A Diagnostic positif Connaître les principaux
#    🧾 Pages ancien PDF : [329]
# ...
# 230. 📄 Texte : A Définition Connaître les facteurs de risque du DG Connaître les critères de sélection
#    🧾 Pages ancien PDF : [643]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [565]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 231. 📄 Texte : B Prise en charge Connaître la surveillance obstétricale sauf prise en charge de la MAP
#    🧾 Pages ancien PDF : [643]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [565]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 232. 📄 Texte : B Deux complications sont particulièrement associées au DG et corrélées de façon positive et
#    🧾 Pages ancien PDF : [645]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 16777215}
#    🧾 Pages nouveau PDF : [568]
#    🎨 Couleurs nouveau PDF : {1269409, 16777215}
# --------------------------------------------------------------------------------
# 233. 📄 Texte : A Le DG expose à un risque ultérieur accru de :
#    🧾 Pages ancien PDF : [646]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [568]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 234. 📄 Texte : A Définition Connaître la définition
#    🧾 Pages ancien PDF : [654]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [574]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 235. 📄 Texte : A Diagnostic positif Connaître les complications de la prééclampsie
#    🧾 Pages ancien PDF : [654]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [574]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 236. 📄 Texte : B Prise en charge Connaître les principes
#    🧾 Pages ancien PDF : [655]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [575]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 237. 📄 Texte : B Suivi et/ou pronostic Connaître les principes
#    🧾 Pages ancien PDF : [655]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [575]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 238. 📄 Texte : B Suivi et/ou pronostic Connaître les éléments
#    🧾 Pages ancien PDF : [655]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [575]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 239. 📄 Texte : Tableau 34.1. B Facteurs de risque de prééclampsie (PE).
#    🧾 Pages ancien PDF : [655]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [576]
#    🎨 Couleurs nouveau PDF : {1269409, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 240. 📄 Texte : B Il comporte :
#    🧾 Pages ancien PDF : [658]
#    🎨 Couleurs ancien PDF : {2301728, 26548, 16777215}
#    🧾 Pages nouveau PDF : [578]
#    🎨 Couleurs nouveau PDF : {1269409, 16777215}
# --------------------------------------------------------------------------------
# 241. 📄 Texte : A Étiologie Facteurs de risque Connaître les principaux risques professionnels, physiques,
#    🧾 Pages ancien PDF : [665]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [584]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 242. 📄 Texte : A Elles consistent à :
#    🧾 Pages ancien PDF : [673]
#    🎨 Couleurs ancien PDF : {2301728, 16777215}
#    🧾 Pages nouveau PDF : [592]
#    🎨 Couleurs nouveau PDF : {2894120, 16777215}
# --------------------------------------------------------------------------------
# 243. 📄 Texte : Tableau 35.2. A Durée du congé de maternité pour les grossesses multiples.
#    🧾 Pages ancien PDF : [674]
#    🎨 Couleurs ancien PDF : {2301728, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [593]
#    🎨 Couleurs nouveau PDF : {2894120, 14165546, 16777215}
# --------------------------------------------------------------------------------
# 244. 📄 Texte : Tableau 35.3. C Classification européenne des substances toxiques pour la reproduction (réglementation CLP – Classification, Labelling and Packaging).
#    🧾 Pages ancien PDF : [678]
#    🎨 Couleurs ancien PDF : {2301728, 695875, 15539236, 16777215}
#    🧾 Pages nouveau PDF : [595]
#    🎨 Couleurs nouveau PDF : {14165546, 1340219, 16777215}
# --------------------------------------------------------------------------------
#
# 📘 Couples de pages avec changement de couleur détecté (170 couples uniques) :
#
# Ancien PDF : page (27,)  ⇄  Nouveau PDF : page (26,)
# Ancien PDF : page (40,)  ⇄  Nouveau PDF : page (39,)
# Ancien PDF : page (41, 90, 561)  ⇄  Nouveau PDF : page (96, 40, 489, 490, 86, 88, 90, 92, 94)
# Ancien PDF : page (48,)  ⇄  Nouveau PDF : page (48,)
# Ancien PDF : page (52,)  ⇄  Nouveau PDF : page (50,)
# Ancien PDF : page (52,)  ⇄  Nouveau PDF : page (51,)
# Ancien PDF : page (53,)  ⇄  Nouveau PDF : page (51,)
# Ancien PDF : page (53,)  ⇄  Nouveau PDF : page (52,)
# Ancien PDF : page (54,)  ⇄  Nouveau PDF : page (52,)
# Ancien PDF : page (54,)  ⇄  Nouveau PDF : page (53,)
# Ancien PDF : page (55,)  ⇄  Nouveau PDF : page (54,)
# Ancien PDF : page (57,)  ⇄  Nouveau PDF : page (57,)
# Ancien PDF : page (59,)  ⇄  Nouveau PDF : page (59,)
# Ancien PDF : page (65, 586, 319)  ⇄  Nouveau PDF : page (513, 514, 516, 518, 520, 522, 524, 526, 528, 530, 278, 63)
# Ancien PDF : page (68,)  ⇄  Nouveau PDF : page (67,)
# Ancien PDF : page (68, 517, 518, 39, 559, 561, 573)  ⇄  Nouveau PDF : page (67, 68, 452, 70, 38, 72, 489, 74, 490, 76, 502)
# Ancien PDF : page (72, 561, 548, 821)  ⇄  Nouveau PDF : page (480, 71, 490, 727, 478)
# Ancien PDF : page (80,)  ⇄  Nouveau PDF : page (77, 87)
# Ancien PDF : page (80,)  ⇄  Nouveau PDF : page (78,)
# Ancien PDF : page (86,)  ⇄  Nouveau PDF : page (84,)
# Ancien PDF : page (88, 319)  ⇄  Nouveau PDF : page (85, 278)
# Ancien PDF : page (90,)  ⇄  Nouveau PDF : page (86,)
# Ancien PDF : page (91,)  ⇄  Nouveau PDF : page (87,)
# Ancien PDF : page (98,)  ⇄  Nouveau PDF : page (95,)
# Ancien PDF : page (99,)  ⇄  Nouveau PDF : page (95,)
# Ancien PDF : page (99, 219)  ⇄  Nouveau PDF : page (96, 200)
# Ancien PDF : page (99, 319)  ⇄  Nouveau PDF : page (278, 95)
# Ancien PDF : page (102,)  ⇄  Nouveau PDF : page (97,)
# Ancien PDF : page (103,)  ⇄  Nouveau PDF : page (97,)
# Ancien PDF : page (103,)  ⇄  Nouveau PDF : page (98,)
# Ancien PDF : page (108,)  ⇄  Nouveau PDF : page (102,)
# Ancien PDF : page (109, 319)  ⇄  Nouveau PDF : page (105, 278)
# Ancien PDF : page (115,)  ⇄  Nouveau PDF : page (109,)
# Ancien PDF : page (116,)  ⇄  Nouveau PDF : page (110,)
# Ancien PDF : page (116, 381)  ⇄  Nouveau PDF : page (183,)
# Ancien PDF : page (117,)  ⇄  Nouveau PDF : page (112,)
# Ancien PDF : page (120, 319)  ⇄  Nouveau PDF : page (115, 278)
# Ancien PDF : page (121,)  ⇄  Nouveau PDF : page (114,)
# Ancien PDF : page (126,)  ⇄  Nouveau PDF : page (118,)
# Ancien PDF : page (133,)  ⇄  Nouveau PDF : page (124,)
# Ancien PDF : page (138,)  ⇄  Nouveau PDF : page (129,)
# Ancien PDF : page (144,)  ⇄  Nouveau PDF : page (136,)
# Ancien PDF : page (147,)  ⇄  Nouveau PDF : page (137,)
# Ancien PDF : page (153,)  ⇄  Nouveau PDF : page (144,)
# Ancien PDF : page (154,)  ⇄  Nouveau PDF : page (145,)
# Ancien PDF : page (155,)  ⇄  Nouveau PDF : page (146,)
# Ancien PDF : page (160,)  ⇄  Nouveau PDF : page (150,)
# Ancien PDF : page (160, 46, 559)  ⇄  Nouveau PDF : page (160, 265, 489, 45, 150, 152, 154, 156, 158)
# Ancien PDF : page (161, 450, 195, 329, 618, 235, 173, 654, 529, 148, 182, 406, 284, 285)  ⇄  Nouveau PDF : page (385, 162, 67, 355, 574, 137, 171, 395, 461, 304, 150, 184, 250, 540, 286, 287)
# Ancien PDF : page (165,)  ⇄  Nouveau PDF : page (155,)
# Ancien PDF : page (173,)  ⇄  Nouveau PDF : page (162,)
# Ancien PDF : page (175,)  ⇄  Nouveau PDF : page (164,)
# Ancien PDF : page (176,)  ⇄  Nouveau PDF : page (165,)
# Ancien PDF : page (179,)  ⇄  Nouveau PDF : page (169,)
# Ancien PDF : page (180,)  ⇄  Nouveau PDF : page (169,)
# Ancien PDF : page (195,)  ⇄  Nouveau PDF : page (183,)
# Ancien PDF : page (195,)  ⇄  Nouveau PDF : page (184,)
# Ancien PDF : page (199,)  ⇄  Nouveau PDF : page (228, 189)
# Ancien PDF : page (209, 319)  ⇄  Nouveau PDF : page (278,)
# Ancien PDF : page (215,)  ⇄  Nouveau PDF : page (195,)
# Ancien PDF : page (216,)  ⇄  Nouveau PDF : page (195,)
# Ancien PDF : page (216,)  ⇄  Nouveau PDF : page (196,)
# Ancien PDF : page (217,)  ⇄  Nouveau PDF : page (198,)
# Ancien PDF : page (218,)  ⇄  Nouveau PDF : page (199,)
# Ancien PDF : page (219,)  ⇄  Nouveau PDF : page (200,)
# Ancien PDF : page (223,)  ⇄  Nouveau PDF : page (203,)
# Ancien PDF : page (223,)  ⇄  Nouveau PDF : page (204,)
# Ancien PDF : page (224,)  ⇄  Nouveau PDF : page (205,)
# Ancien PDF : page (225,)  ⇄  Nouveau PDF : page (206,)
# Ancien PDF : page (234, 53, 319)  ⇄  Nouveau PDF : page (224, 226, 228, 230, 232, 265, 51, 213, 214, 278, 216, 218, 220, 222)
# Ancien PDF : page (235,)  ⇄  Nouveau PDF : page (214,)
# Ancien PDF : page (235, 236, 174)  ⇄  Nouveau PDF : page (162, 67, 548)
# Ancien PDF : page (236,)  ⇄  Nouveau PDF : page (214,)
# Ancien PDF : page (236,)  ⇄  Nouveau PDF : page (215,)
# Ancien PDF : page (238,)  ⇄  Nouveau PDF : page (217,)
# Ancien PDF : page (241,)  ⇄  Nouveau PDF : page (219,)
# Ancien PDF : page (256,)  ⇄  Nouveau PDF : page (230,)
# Ancien PDF : page (257,)  ⇄  Nouveau PDF : page (231,)
# Ancien PDF : page (260, 261, 133, 406, 284)  ⇄  Nouveau PDF : page (355, 233, 234, 250, 123)
# Ancien PDF : page (261,)  ⇄  Nouveau PDF : page (234,)
# Ancien PDF : page (285,)  ⇄  Nouveau PDF : page (250,)
# Ancien PDF : page (285,)  ⇄  Nouveau PDF : page (251,)
# Ancien PDF : page (302,)  ⇄  Nouveau PDF : page (264,)
# Ancien PDF : page (310,)  ⇄  Nouveau PDF : page (271,)
# Ancien PDF : page (310,)  ⇄  Nouveau PDF : page (272,)
# Ancien PDF : page (315,)  ⇄  Nouveau PDF : page (275,)
# Ancien PDF : page (328, 348)  ⇄  Nouveau PDF : page (304, 249, 286)
# Ancien PDF : page (329,)  ⇄  Nouveau PDF : page (286,)
# Ancien PDF : page (330,)  ⇄  Nouveau PDF : page (289,)
# Ancien PDF : page (340,)  ⇄  Nouveau PDF : page (298,)
# Ancien PDF : page (341,)  ⇄  Nouveau PDF : page (298,)
# Ancien PDF : page (347, 380, 558, 223)  ⇄  Nouveau PDF : page (203, 332, 485, 303)
# Ancien PDF : page (348,)  ⇄  Nouveau PDF : page (304,)
# Ancien PDF : page (363, 548, 823)  ⇄  Nouveau PDF : page (729, 478, 318)
# Ancien PDF : page (373,)  ⇄  Nouveau PDF : page (327,)
# Ancien PDF : page (382,)  ⇄  Nouveau PDF : page (334,)
# Ancien PDF : page (383,)  ⇄  Nouveau PDF : page (335,)
# Ancien PDF : page (383,)  ⇄  Nouveau PDF : page (336,)
# Ancien PDF : page (385,)  ⇄  Nouveau PDF : page (338,)
# Ancien PDF : page (386,)  ⇄  Nouveau PDF : page (339,)
# Ancien PDF : page (389,)  ⇄  Nouveau PDF : page (341,)
# Ancien PDF : page (400,)  ⇄  Nouveau PDF : page (351,)
# Ancien PDF : page (406,)  ⇄  Nouveau PDF : page (355,)
# Ancien PDF : page (407,)  ⇄  Nouveau PDF : page (356,)
# Ancien PDF : page (425,)  ⇄  Nouveau PDF : page (373,)
# Ancien PDF : page (430,)  ⇄  Nouveau PDF : page (377,)
# Ancien PDF : page (440,)  ⇄  Nouveau PDF : page (532,)
# Ancien PDF : page (440, 348, 557)  ⇄  Nouveau PDF : page (385,)
# Ancien PDF : page (441,)  ⇄  Nouveau PDF : page (386,)
# Ancien PDF : page (441,)  ⇄  Nouveau PDF : page (387,)
# Ancien PDF : page (449,)  ⇄  Nouveau PDF : page (394,)
# Ancien PDF : page (449, 195, 132, 260, 102, 329, 586, 235, 618, 654, 406, 380, 347, 284)  ⇄  Nouveau PDF : page (67, 355, 574, 233, 394, 332, 303, 183, 184, 249, 250, 123, 540, 286)
# Ancien PDF : page (449, 450, 261, 103, 329, 586, 173, 558, 654, 115, 181, 634, 90, 347, 284)  ⇄  Nouveau PDF : page (162, 547, 485, 574, 234, 171, 394, 109, 77, 303, 395, 556, 565, 87, 249, 286)
# Ancien PDF : page (450,)  ⇄  Nouveau PDF : page (395,)
# Ancien PDF : page (451,)  ⇄  Nouveau PDF : page (395,)
# Ancien PDF : page (451,)  ⇄  Nouveau PDF : page (396,)
# Ancien PDF : page (465,)  ⇄  Nouveau PDF : page (409,)
# Ancien PDF : page (466,)  ⇄  Nouveau PDF : page (410,)
# Ancien PDF : page (466,)  ⇄  Nouveau PDF : page (411,)
# Ancien PDF : page (468,)  ⇄  Nouveau PDF : page (412,)
# Ancien PDF : page (471,)  ⇄  Nouveau PDF : page (416,)
# Ancien PDF : page (475,)  ⇄  Nouveau PDF : page (419,)
# Ancien PDF : page (498,)  ⇄  Nouveau PDF : page (435,)
# Ancien PDF : page (498,)  ⇄  Nouveau PDF : page (436,)
# Ancien PDF : page (513,)  ⇄  Nouveau PDF : page (448,)
# Ancien PDF : page (517, 40, 559, 79, 561, 573)  ⇄  Nouveau PDF : page (39, 265, 489, 490, 77, 78, 80, 82, 84, 502)
# Ancien PDF : page (517, 518, 39, 559, 561, 571, 573)  ⇄  Nouveau PDF : page (452, 453, 38, 40, 489, 42, 490, 44, 46, 48, 500, 502)
# Ancien PDF : page (517, 518, 559, 52, 571, 573)  ⇄  Nouveau PDF : page (64, 66, 452, 453, 265, 489, 50, 52, 500, 54, 502, 56, 58, 60, 62)
# Ancien PDF : page (522,)  ⇄  Nouveau PDF : page (456,)
# Ancien PDF : page (524,)  ⇄  Nouveau PDF : page (457,)
# Ancien PDF : page (531,)  ⇄  Nouveau PDF : page (464,)
# Ancien PDF : page (533,)  ⇄  Nouveau PDF : page (465,)
# Ancien PDF : page (536,)  ⇄  Nouveau PDF : page (467,)
# Ancien PDF : page (536,)  ⇄  Nouveau PDF : page (468,)
# Ancien PDF : page (539,)  ⇄  Nouveau PDF : page (470,)
# Ancien PDF : page (548,)  ⇄  Nouveau PDF : page (478,)
# Ancien PDF : page (550,)  ⇄  Nouveau PDF : page (480,)
# Ancien PDF : page (551, 543)  ⇄  Nouveau PDF : page (482, 475)
# Ancien PDF : page (554,)  ⇄  Nouveau PDF : page (484,)
# Ancien PDF : page (557,)  ⇄  Nouveau PDF : page (485,)
# Ancien PDF : page (557, 528, 529, 348, 440, 90, 347, 380, 381)  ⇄  Nouveau PDF : page (532, 533)
# Ancien PDF : page (559, 147, 45, 319)  ⇄  Nouveau PDF : page (137, 138, 489, 44, 140, 142, 144, 146, 148, 278)
# Ancien PDF : page (561, 42, 102, 559)  ⇄  Nouveau PDF : page (97, 98, 100, 102, 104, 41, 106, 265, 108, 489, 490)
# Ancien PDF : page (564,)  ⇄  Nouveau PDF : page (493,)
# Ancien PDF : page (567,)  ⇄  Nouveau PDF : page (497,)
# Ancien PDF : page (587,)  ⇄  Nouveau PDF : page (515,)
# Ancien PDF : page (592,)  ⇄  Nouveau PDF : page (519,)
# Ancien PDF : page (592,)  ⇄  Nouveau PDF : page (520,)
# Ancien PDF : page (595,)  ⇄  Nouveau PDF : page (523,)
# Ancien PDF : page (611,)  ⇄  Nouveau PDF : page (536,)
# Ancien PDF : page (611,)  ⇄  Nouveau PDF : page (537,)
# Ancien PDF : page (612,)  ⇄  Nouveau PDF : page (537,)
# Ancien PDF : page (614,)  ⇄  Nouveau PDF : page (539,)
# Ancien PDF : page (620,)  ⇄  Nouveau PDF : page (544,)
# Ancien PDF : page (621,)  ⇄  Nouveau PDF : page (545,)
# Ancien PDF : page (622,)  ⇄  Nouveau PDF : page (542,)
# Ancien PDF : page (634,)  ⇄  Nouveau PDF : page (556,)
# Ancien PDF : page (637,)  ⇄  Nouveau PDF : page (560,)
# Ancien PDF : page (643,)  ⇄  Nouveau PDF : page (565,)
# Ancien PDF : page (645,)  ⇄  Nouveau PDF : page (568,)
# Ancien PDF : page (646,)  ⇄  Nouveau PDF : page (568,)
# Ancien PDF : page (654,)  ⇄  Nouveau PDF : page (574,)
# Ancien PDF : page (655,)  ⇄  Nouveau PDF : page (575,)
# Ancien PDF : page (655,)  ⇄  Nouveau PDF : page (576,)
# Ancien PDF : page (658,)  ⇄  Nouveau PDF : page (578,)
# Ancien PDF : page (665,)  ⇄  Nouveau PDF : page (584,)
# Ancien PDF : page (673,)  ⇄  Nouveau PDF : page (592,)
# Ancien PDF : page (674,)  ⇄  Nouveau PDF : page (593,)
# Ancien PDF : page (678,)  ⇄  Nouveau PDF : page (595,)
# Ancien PDF : page (768, 769, 770, 12, 689, 690, 691, 692, 693, 694, 695, 696, 726, 727, 728, 729, 730, 731, 732, 733, 734, 736, 737, 738, 739, 740, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 756, 758, 759, 760, 761, 762, 763, 764, 765, 767)  ⇄  Nouveau PDF : page (11, 666, 667, 668, 669, 671, 673, 674, 676, 677, 678, 679, 680, 682, 684, 686, 687, 688, 689, 690, 691, 692, 693, 694, 695, 696, 698, 699, 700, 701, 702, 703, 704, 705, 706, 707, 708, 710, 713)
